# %%
import pandas as pd

# %%
from services.queries import get_league_averages
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from services.queries import get_league_averages
#
# File c:\Users\lkwas\Desktop\Data_engineering\Football-dashboard-app\services\queries.py:7
#       5 from sqlalchemy.orm import Session
#       6 import pandas as pd
# ----> 7 from models.league_averages import LeagueAverages
#       8 from services.db import get_engine
#       9 from services.cache import cache_query_result
#
# ModuleNotFoundError: No module named 'models'
